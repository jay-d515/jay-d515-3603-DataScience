# %% [markdown]
# # 📈 05 - Plotting Basics
#
# Visualization is a core part of data science.
# In this notebook you will learn:
# - Setting up Matplotlib for inline plotting
# - Creating simple line, scatter, and bar plots
# - Customizing titles, labels, and legends
# - Why visuals matter in data storytelling

# %% [markdown]
# ```
# # Name: Jadyn Dangerfield
# # Assignment: 05-Plotting Basics
# ```

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label="sin(x)")
plt.title("Line Plot Example")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Plot `cos(x)` on the same graph with a different color and label.

# %%
x1 = np.linspace(0, 10, 100)
y1 = np.cos(x1)

plt.plot(x1, y1, label="cos(x)", color="red")
plt.title("My Line Plot")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 300 * np.random.rand(50)
colors = np.random.rand(50)

plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Generate two sets of random points and plot them in different colors on the same scatter plot.

# %%
# generate two sets of random points in different colors
x1 = np.random.rand(50)
y1 = np.random.rand(50)
sizes1 = 300 * np.random.rand(50)
colors1 = np.random.rand(50)

x2 = np.random.rand(50)
y2 = np.random.rand(50)
sizes2 = 300 * np.random.rand(50)
colors2 = np.random.rand(50)

# plots teh random points on the same scatter plot
plt.scatter(x1, y1, s=sizes1, c=colors1, alpha=0.6, cmap='viridis')
plt.scatter(x2, y2, s=sizes2, c=colors2, alpha=0.6, cmap='viridis')
plt.title("My Scatter Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ## 4. Bar Plot

# %%
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

plt.bar(categories, values)
plt.title("Bar Plot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Create your own bar chart with at least 4 categories (e.g., favorite foods, courses, or hobbies).

# %%
fruits = ["watermelon", "mango", "strawberries", "apples"]
my_values = [3, 6, 4, 8]

plt.bar(fruits, my_values)
plt.title("Favorite Fruits")
plt.xlabel("Fruits")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## 5. Customizing Plots

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="sin(x)", linestyle="--", color="blue")
plt.plot(x, y2, label="cos(x)", linestyle=":", color="red")
plt.title("Customized Line Plot")
plt.xlabel("x (radians)")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Customize your own plot with labels, legend, and grid lines.

# %%
x1 = np.linspace(0, 2*np.pi, 100)
my_y1 = np.sin(x)
my_y2 = np.tan(x)

plt.plot(x1, my_y1, label="sin(x)", linestyle="--", color="green")
plt.plot(x1, my_y2, label="tan(x)", linestyle=":", color="orange")
plt.title("My Customized Line Plot")
plt.xlabel("x (radians)")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ### Summary
# - `%matplotlib inline` makes plots display inside the notebook.
# - Line, scatter, and bar plots are the most common basics.
# - Titles, labels, legends, and grids improve readability.
# - Visuals tell stories about data more effectively than raw numbers.
