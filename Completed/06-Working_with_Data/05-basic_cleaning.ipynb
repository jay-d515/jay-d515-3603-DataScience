# %% [markdown]
# ```
# # Jadyn Dangerfield
# # Assignment: 05 Basic Cleaning
# ```

# %% [markdown]
# # 🧼 Cleaning Dirty Data (Missing Values & Type Fixes)
#
# ## 🔹 LEARNING GOALS:
# - Detect and count missing values (`NaN`)
# - Fill or drop missing data
# - Convert column data types safely
# - Understand the difference between `NaN`, `None`, `""`, and type mismatches

# %% [markdown]
# ### 🧪 1. Load a Messy Dataset

# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", None],
    "Age": ["25", "thirty", 35, np.nan, "40"],
    "Signup Date": ["2022-01-01", "not a date", "2022/03/01", None, "April 5, 2022"],
    "Score": [95.5, None, 88.0, 92.5, ""]
}

df = pd.DataFrame(data)
df
# Out:
#       Name     Age    Signup Date Score
# 0    Alice      25     2022-01-01  95.5
# 1      Bob  thirty     not a date  None
# 2  Charlie      35     2022/03/01  88.0
# 3    David     NaN           None  92.5
# 4     None      40  April 5, 2022

# %% [markdown]
# ### 🧯 2. Detecting Missing or Broken Values

# %%
df.isnull()
# Out:
#     Name    Age  Signup Date  Score
# 0  False  False        False  False
# 1  False  False        False   True
# 2  False  False        False  False
# 3  False   True         True  False
# 4   True  False        False  False

# %%
df.isnull().sum()
# Out:
# Name           1
# Age            1
# Signup Date    1
# Score          1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Name     Age    Signup Date Score
# 1    Bob  thirty     not a date  None
# 3  David     NaN           None  92.5
# 4   None      40  April 5, 2022

# %% [markdown]
# ### 🧹 3. Cleaning Strategy Options

# %%
df.fillna({
    "Name": "Unknown",
    "Age": -1,
    "Signup Date": "1970-01-01",
    "Score": 0.0
})
# Out:
#       Name     Age    Signup Date Score
# 0    Alice      25     2022-01-01  95.5
# 1      Bob  thirty     not a date   0.0
# 2  Charlie      35     2022/03/01  88.0
# 3    David      -1     1970-01-01  92.5
# 4  Unknown      40  April 5, 2022

# %%
df.dropna()
# Out:
#       Name Age Signup Date Score
# 0    Alice  25  2022-01-01  95.5
# 2  Charlie  35  2022/03/01  88.0

# %% [markdown]
# ### 🧬 4. Data Type Fixes

# %%
df.dtypes
# Out:
# Name           object
# Age            object
# Signup Date    object
# Score          object
# dtype: object

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df["Score"] = pd.to_numeric(df["Score"], errors="coerce")
df["Signup Date"] = pd.to_datetime(df["Signup Date"], errors="coerce")
df.dtypes
# Out:
# Name                   object
# Age                   float64
# Signup Date    datetime64[ns]
# Score                 float64
# dtype: object

# %% [markdown]
# ### 🩹 5. Impute (Fill In) Fixed Missing Values

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Score"].fillna(df["Score"].mean(), inplace=True)
# Out:
# /tmp/ipython-input-1713118361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# /tmp/ipython-input-1713118361.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(df["Score"].mean(), inplace=True)

# %%
df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)
# Out:
# /tmp/ipython-input-3000949103.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)

# %%
df["Name"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipython-input-626038248.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name"].fillna("Unknown", inplace=True)

# %% [markdown]
# ### 🤓 6. Cleaned Data Review

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      object
#  1   Age          5 non-null      float64
#  2   Signup Date  5 non-null      datetime64[ns]
#  3   Score        5 non-null      float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 292.0+ bytes

# %%
df.describe(include="all")
# Out:
#          Name        Age          Signup Date     Score
# count       5   5.000000                    5   5.00000
# unique      5        NaN                  NaN       NaN
# top     Alice        NaN                  NaN       NaN
# freq        1        NaN                  NaN       NaN
# mean      NaN  34.000000  2022-01-01 00:00:00  92.00000
# min       NaN  25.000000  2022-01-01 00:00:00  88.00000
# 25%       NaN  35.000000  2022-01-01 00:00:00  92.00000
# 50%       NaN  35.000000  2022-01-01 00:00:00  92.00000
# 75%       NaN  35.000000  2022-01-01 00:00:00  92.50000
# max       NaN  40.000000  2022-01-01 00:00:00  95.50000
# std       NaN   5.477226                  NaN   2.66927

# %% [markdown]
# ### 🧪 Try It Yourself
#
# Modify the `data` dictionary at the top of this notebook. Add:
# - A new column with some `None` and `""` values
# - At least one row with all columns filled incorrectly
# Then re-run the notebook and fix it step-by-step.

# %%
# Add a new column with some None and "" values
df["New Column"] = [None, "Sup", "Hello", "Hi", np.nan]
df
# Out:
#       Name   Age Signup Date  Score New Column
# 0    Alice  25.0  2022-01-01   95.5       None
# 1      Bob  35.0  2022-01-01   92.0        Sup
# 2  Charlie  35.0  2022-01-01   88.0      Hello
# 3    David  35.0  2022-01-01   92.5         Hi
# 4  Unknown  40.0  2022-01-01   92.0        NaN

# %%
# Add a new row with all columns filled incorrectly
df.loc[len(df)] = [None, np.nan, "", "", None]
df
# Out:
#       Name   Age          Signup Date Score New Column
# 0    Alice  25.0  2022-01-01 00:00:00  95.5       None
# 1      Bob  35.0  2022-01-01 00:00:00  92.0        Sup
# 2  Charlie  35.0  2022-01-01 00:00:00  88.0      Hello
# 3    David  35.0  2022-01-01 00:00:00  92.5         Hi
# 4  Unknown  40.0  2022-01-01 00:00:00  92.0        NaN
# 5     None   NaN                                  None

# %%
# Fix it

# Detect missing/broken values
df.isnull()
# Out:
#     Name    Age  Signup Date  Score  New Column
# 0  False  False        False  False        True
# 1  False  False        False  False       False
# 2  False  False        False  False       False
# 3  False  False        False  False       False
# 4  False  False        False  False        True
# 5   True   True        False  False        True

# %%
df.isnull().sum()
# Out:
# Name           1
# Age            1
# Signup Date    0
# Score          0
# New Column     3
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Name   Age          Signup Date Score New Column
# 0    Alice  25.0  2022-01-01 00:00:00  95.5       None
# 4  Unknown  40.0  2022-01-01 00:00:00  92.0        NaN
# 5     None   NaN                                  None

# %%
df.dtypes
# Out:
# Name            object
# Age            float64
# Signup Date     object
# Score           object
# New Column      object
# dtype: object

# %%
df["Score"] = pd.to_numeric(df["Score"], errors="coerce")
df["Signup Date"] = pd.to_datetime(df["Signup Date"], errors="coerce")
df.dtypes
# Out:
# Name                   object
# Age                   float64
# Signup Date    datetime64[ns]
# Score                 float64
# New Column             object
# dtype: object

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Score"].fillna(df["Score"].mean(), inplace=True)
df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)
df["Name"].fillna("Unknown", inplace=True)
df["New Column"].fillna("Hi", inplace=True)
# Out:
# /tmp/ipython-input-3177585560.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# /tmp/ipython-input-3177585560.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(df["Score"].mean(), inplace=True)
# /tmp/ipython-input-3177585560.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)
# /tmp/ipython-input-3177585560.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name"].fillna("Unknown", inplace=True)
# /tmp/ipython-input-3177585560.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["New Column"].fillna("Hi", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         6 non-null      object
#  1   Age          6 non-null      float64
#  2   Signup Date  6 non-null      datetime64[ns]
#  3   Score        6 non-null      float64
#  4   New Column   6 non-null      object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 460.0+ bytes

# %%
df.describe(include="all")
# Out:
#            Name        Age          Signup Date      Score New Column
# count         6   6.000000                    6   6.000000          6
# unique        5        NaN                  NaN        NaN          3
# top     Unknown        NaN                  NaN        NaN         Hi
# freq          2        NaN                  NaN        NaN          4
# mean        NaN  34.166667  2022-01-01 00:00:00  92.000000        NaN
# min         NaN  25.000000  2022-01-01 00:00:00  88.000000        NaN
# 25%         NaN  35.000000  2022-01-01 00:00:00  92.000000        NaN
# 50%         NaN  35.000000  2022-01-01 00:00:00  92.000000        NaN
# 75%         NaN  35.000000  2022-01-01 00:00:00  92.375000        NaN
# max         NaN  40.000000  2022-01-01 00:00:00  95.500000        NaN
# std         NaN   4.915960                  NaN   2.387467        NaN

# %%
df
# Out:
#       Name   Age Signup Date  Score New Column
# 0    Alice  25.0  2022-01-01   95.5         Hi
# 1      Bob  35.0  2022-01-01   92.0        Sup
# 2  Charlie  35.0  2022-01-01   88.0      Hello
# 3    David  35.0  2022-01-01   92.5         Hi
# 4  Unknown  40.0  2022-01-01   92.0         Hi
# 5  Unknown  35.0  2022-01-01   92.0         Hi

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > 🗂 Load `"data/survey.csv"` and:
# - Identify which columns have missing values
# - Use `.isnull().sum()` to get a null report
# - Use a mix of `.fillna()`, `.dropna()`, and `pd.to_numeric()` or `pd.to_datetime()` to clean it
# - Print a summary with `.info()` and `.describe()`

# %%
# Load data in
survey_df = pd.read_csv("survey.csv")
survey_df
# Out:
#   FirstName     LastName  SignupDate SurveyCompleted   Age
# 0     Jadyn  Dangerfield  10/15/2025             Yes  21.0
# 1     Maria        Lopez   9/30/2025              No  22.0
# 2     Ethan          Kim   10/5/2025             NaN  22.0
# 3     Sarah          NaN  10/20/2025             Yes  22.0
# 4     James       Nguyen         NaN              No  22.0
# 5    Olivia        Brown  10/12/2025             Yes   NaN
# 6       NaN      Johnson   10/8/2025              No  30.0
# 7   Michael        Clark  10/25/2025             Yes  27.0
# 8    Sophia       Turner   10/2/2025             NaN  23.0
# 9    Daniel        White   9/29/2025              No   NaN

# %%
# Identify which columns have missing values
survey_df.isnull().sum()
# Out:
# FirstName          1
# LastName           1
# SignupDate         1
# SurveyCompleted    2
# Age                2
# dtype: int64

# %%
# Use a mix of .fillna(), .dropna(), and pd.to_numeric() or pd.to_datetime() to clean it
survey_df[survey_df.isnull().any(axis=1)]
# Out:
#   FirstName LastName  SignupDate SurveyCompleted   Age
# 2     Ethan      Kim   10/5/2025             NaN  22.0
# 3     Sarah      NaN  10/20/2025             Yes  22.0
# 4     James   Nguyen         NaN              No  22.0
# 5    Olivia    Brown  10/12/2025             Yes   NaN
# 6       NaN  Johnson   10/8/2025              No  30.0
# 8    Sophia   Turner   10/2/2025             NaN  23.0
# 9    Daniel    White   9/29/2025              No   NaN

# %%
survey_df.dtypes
# Out:
# FirstName           object
# LastName            object
# SignupDate          object
# SurveyCompleted     object
# Age                float64
# dtype: object

# %%
survey_df["Age"] = pd.to_numeric(survey_df["Age"], errors="coerce")
survey_df["SignupDate"] = pd.to_datetime(survey_df["SignupDate"], errors="coerce")
survey_df.dtypes
# Out:
# FirstName                  object
# LastName                   object
# SignupDate         datetime64[ns]
# SurveyCompleted            object
# Age                       float64
# dtype: object

# %%
survey_df["Age"].fillna(survey_df["Age"].median(), inplace=True)
survey_df["SurveyCompleted"].fillna("Yes", inplace=True)
survey_df["SignupDate"].fillna(survey_df["SignupDate"].min(), inplace=True)
survey_df["FirstName"].fillna("Unknown", inplace=True)
survey_df["LastName"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipython-input-2403760668.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   survey_df["Age"].fillna(survey_df["Age"].median(), inplace=True)
# /tmp/ipython-input-2403760668.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   survey_df["SurveyCompleted"].fillna("Yes", inplace=True)
# /tmp/ipython-input-2403760668.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   survey_df["SignupDate"].fillna(survey_df["SignupDate"].min(), inplace=True)
# /tmp/ipython-input-2403760668.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   survey_df["FirstName"].fillna("Unknown", inplace=True)
# /tmp/ipython-input-2403760668.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   survey_df["LastName"].fillna("Unknown", inplace=True)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FirstName        10 non-null     object
#  1   LastName         10 non-null     object
#  2   SignupDate       10 non-null     datetime64[ns]
#  3   SurveyCompleted  10 non-null     object
#  4   Age              10 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 532.0+ bytes

# %%
survey_df.describe()
# Out:
#                 SignupDate        Age
# count                   10  10.000000
# mean   2025-10-08 12:00:00  25.900000
# min    2025-09-29 00:00:00  21.000000
# 25%    2025-09-30 12:00:00  22.000000
# 50%    2025-10-06 12:00:00  22.500000
# 75%    2025-10-14 06:00:00  29.250000
# max    2025-10-25 00:00:00  35.000000
# std                    NaN   5.546771

# %%
survey_df
# Out:
#   FirstName     LastName SignupDate SurveyCompleted   Age
# 0     Jadyn  Dangerfield 2025-10-15             Yes  21.0
# 1     Maria        Lopez 2025-09-30              No  22.0
# 2     Ethan          Kim 2025-10-05             Yes  22.0
# 3     Sarah      Unknown 2025-10-20             Yes  22.0
# 4     James       Nguyen 2025-09-29              No  22.0
# 5    Olivia        Brown 2025-10-12             Yes  35.0
# 6   Unknown      Johnson 2025-10-08              No  30.0
# 7   Michael        Clark 2025-10-25             Yes  27.0
# 8    Sophia       Turner 2025-10-02             Yes  23.0
# 9    Daniel        White 2025-09-29              No  35.0

# %% [markdown]
# ### 📝 Summary
#
# | Concept        | Tool/Function                      |
# |----------------|------------------------------------|
# | Detect nulls   | `df.isnull()`, `df.isnull().sum()` |
# | Drop rows      | `df.dropna()`                      |
# | Fill values    | `df.fillna()`                      |
# | Convert types  | `pd.to_numeric()`, `pd.to_datetime()` |
# | Replace values | `df.replace()`                     |
